# %% [markdown]
# <a href="https://colab.research.google.com/github/Rikiimam16/myprojecttif/blob/main/identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Menampilkan Judul
print("========================================================")
print("                  DATA DIRI MAHASISWA")
print("========================================================")

#Menampilkan Nama Lengkap
print("Nama                 : M. Riki Imamuddin")

#Menampilkan NIM
print("NIM                  : 2605060009")

#Menampilkan Tempat, Tanggal Lahir
print("Tempat, Tanggal Lahir: Pekalongan, 20 Maret 2008")

#Menampilkan Alamat
print("Alamat               : Kab. Pekalongan, Jawa Tengah")

#Menampilkan Jenis Kelamin
print("Jenis Kelamin        : Laki-laki")

#Menampilkan Hobi
print("Hobi                 : Mendengarkan Musik")

# Menampilkan garis penutup
print("========================================================")
# Out:
# ...
#                   DATA DIRI MAHASISWA
# ...
# Nama                 : M. Riki Imamuddin
# NIM                  : 2605060009
# Tempat, Tanggal Lahir: Pekalongan, 20 Maret 2008
# Alamat               : Kab. Pekalongan, Jawa Tengah
# Jenis Kelamin        : Laki-laki
# Hobi                 : Mendengarkan Musik
# ...
